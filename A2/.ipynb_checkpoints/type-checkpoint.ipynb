# %%
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image, UnidentifiedImageError
from PIL import Image, ImageOps
from tensorflow.keras import layers, models
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
import tensorflow as tf
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %%
import os
from PIL import Image, UnidentifiedImageError

# Root directory of the images
root_dir = 'trafficsigns_dataset'  # Replace with the actual path

# Nested dictionary to store images categorized by two levels of labels
images_by_label = {}

# Function to traverse the dataset and load images and their labels
def load_images_and_labels(root_dir):
    # Iterate through each subdirectory in the root directory (first level)
    for sub_dir in os.listdir(root_dir):
        sub_dir_path = os.path.join(root_dir, sub_dir)
        
        # Check if the subdirectory is indeed a directory
        if os.path.isdir(sub_dir_path):
            # Initialize the first level label key
            images_by_label[sub_dir] = {}
            
            # Iterate again through the folders within the subdirectory (second level, specific labels)
            for label_dir in os.listdir(sub_dir_path):
                label_dir_path = os.path.join(sub_dir_path, label_dir)
                
                # Check if the second level is also a directory
                if os.path.isdir(label_dir_path):
                    # Initialize the second level label key
                    images_by_label[sub_dir][label_dir] = []
                    
                    # Iterate through all image files in the second level directory
                    for image_filename in os.listdir(label_dir_path):
                        # Ignore .DS_Store files
                        if image_filename == '.DS_Store':
                            continue
                        image_path = os.path.join(label_dir_path, image_filename)
                        try:
                            images_by_label[sub_dir][label_dir].append(image_path)
                        except UnidentifiedImageError:
                            # Print error message if the image cannot be identified
                            print(f"Cannot identify image file '{image_path}'")

# Load images and labels
load_images_and_labels(root_dir)

# Print the number of images for each category
for sub_dir, labels in images_by_label.items():
    for label, images in labels.items():
        print(f"{sub_dir}/{label}: {len(images)} images")
        
label_names = []
for sub_dir in images_by_label:
    for label in images_by_label[sub_dir]:
        if label not in label_names:
            label_names.append(label)

# Sort label names to maintain consistency
label_names.sort()

# Now label_names contains all unique labels, sorted alphabetically
# Out:
# diamond/rightofway: 282 images
# hex/stop: 43 images
# square/laneend: 118 images
# square/parking: 276 images
# square/continue: 199 images
# square/crossing: 95 images
# triangle/giveway: 231 images
# triangle/warning: 695 images
# round/traveldirection: 124 images
# round/limitedtraffic: 125 images
# round/speed: 316 images
# round/roundabout: 98 images
# round/noentry: 375 images
# round/noparking: 242 images
# round/bicycle: 285 images
# round/trafficdirective: 195 images

# %% [markdown]
# 28no Unusual

# %%
def get_image_sizes(root_dir):
    sizes = []
    # Traverse through the directory structure in root_dir
    for subdir, dirs, files in os.walk(root_dir):
        for file in files:
            # Check if the file is a PNG or JPG
            if file.lower().endswith('.png') or file.lower().endswith('.jpg'):
                try:
                    # Open the image file and append its size (width, height)
                    with Image.open(os.path.join(subdir, file)) as img:
                        sizes.append(img.size)
                except (IOError, UnidentifiedImageError):
                    # Continue to the next file if an error occurs
                    continue
    return sizes

# Call the function to get the sizes of all images in the directory
image_sizes = get_image_sizes(root_dir)

# Convert list of sizes to a NumPy array for statistical calculation
sizes_np = np.array(image_sizes)
min_size = sizes_np.min(axis=0)
max_size = sizes_np.max(axis=0)
mean_size = sizes_np.mean(axis=0)
std_dev_size = sizes_np.std(axis=0)
median_size = np.median(sizes_np, axis=0)

# Output the minimum, maximum, mean, standard deviation, and median sizes of the images
min_size, max_size, mean_size, std_dev_size, median_size
# Out:
# (array([28, 28]),
#  array([28, 28]),
#  array([28., 28.]),
#  array([0., 0.]),
#  array([28., 28.]))

# %%
train_data = {}
test_data = {}
validation_data = {}

for first_level, second_level_dict in images_by_label.items():
    train_data[first_level] = {}
    validation_data[first_level] = {}
    test_data[first_level] = {}
    
    for label, image_paths in second_level_dict.items():
        temp_images, test_images = train_test_split(image_paths, test_size=0.2, random_state=42)
        train_images, val_images = train_test_split(temp_images, test_size=0.2, random_state=42)
        
        # Save split data
        train_data[first_level][label] = train_images
        test_data[first_level][label] = test_images
        validation_data[first_level][label] = val_images

# %%
def create_dataframe_for_16_class(data_dict):
    rows = []
    for first_level, second_level_dict in data_dict.items():
        for label, image_paths in second_level_dict.items():
            for path in image_paths:
                rows.append({'ImagePath': path, 'Label': label})
    return pd.DataFrame(rows)

def create_dataframe_for_5_class(data_dict):
    rows = []
    for first_level, second_level_dict in data_dict.items():
        for label, image_paths in second_level_dict.items():
            for path in image_paths:
                rows.append({'ImagePath': path, 'Label': first_level})
    return pd.DataFrame(rows)

train_df = create_dataframe_for_16_class(train_data)
test_df = create_dataframe_for_16_class(test_data)
validation_df = create_dataframe_for_16_class(validation_data)

# %%
batch_size = 64

# %%
# Initialize image data generators with rescaling
train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)
val_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)
test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)

# Create a training data generator from a dataframe
train_generator = train_datagen.flow_from_dataframe(
    dataframe=train_df,
    x_col='ImagePath',          # Column in dataframe that contains the image paths
    y_col='Label',              # Column in dataframe that contains the labels
    color_mode='grayscale',     # Use grayscale images
    target_size=(28, 28),       # Resize images to 28x28 pixels
    batch_size=batch_size,      # Number of images to process in a batch
    class_mode='categorical',   # If it's a multi-class problem
    shuffle=True                # Shuffle the order of the images
)

# Create a validation data generator from a dataframe
val_generator = val_datagen.flow_from_dataframe(
    dataframe=validation_df,
    x_col='ImagePath',          # Column in dataframe that contains the image paths
    y_col='Label',              # Column in dataframe that contains the labels
    color_mode='grayscale',     # Use grayscale images
    target_size=(28, 28),       # Resize images to 28x28 pixels
    batch_size=batch_size,      # Number of images to process in a batch
    class_mode='categorical',   # If it's a multi-class problem
    shuffle=False               # Do not shuffle the images
)

# Create a test data generator from a dataframe
test_generator = test_datagen.flow_from_dataframe(
    dataframe=test_df,
    x_col='ImagePath',          # Column in dataframe that contains the image paths
    y_col='Label',              # Column in dataframe that contains the labels
    color_mode='grayscale',     # Use grayscale images
    target_size=(28, 28),       # Resize images to 28x28 pixels
    batch_size=batch_size,      # Number of images to process in a batch
    class_mode='categorical',   # If it's a multi-class problem
    shuffle=False               # Do not shuffle the images
)
# Out:
# Found 2358 validated image filenames belonging to 16 classes.
# Found 596 validated image filenames belonging to 16 classes.
# Found 745 validated image filenames belonging to 16 classes.

# %% [markdown]
# ## Transfer data to suit scikit-learn

# %%
import numpy as np

def get_data_from_generator(generator):
    batches = []
    labels = []
    # Iterate over the generator to collect data and labels
    for batch, label in generator:
        batches.append(batch)
        labels.append(label)
        if len(batches) >= len(generator):
            break  # Ensure not to iterate infinitely
    return np.vstack(batches), np.vstack(labels)

# Get training, validation, and test data and labels
X_train, y_train = get_data_from_generator(train_generator)
X_val, y_val = get_data_from_generator(val_generator)
X_test, y_test = get_data_from_generator(test_generator)

# %% [markdown]
# ## Decision Tree

# %%
# Assume the original shape of X_train and X_val is [number of samples, 28, 28, 1] - as extracted from an image generator

# Reshape X_train and X_val into two-dimensional arrays, one row per image
X_train = X_train.reshape(X_train.shape[0], -1)  # -1 calculates the necessary size based on the remaining dimensions
X_val = X_val.reshape(X_val.shape[0], -1)

# If using get_data_from_generator function to extract data, make sure to adjust the function or data before reshaping
# For example, ensure data is correctly extracted and transformed from the generator
X_train, y_train = get_data_from_generator(train_generator)
X_train = X_train.reshape(X_train.shape[0], -1)

X_val, y_val = get_data_from_generator(val_generator)
X_val = X_val.reshape(X_val.shape[0], -1)

# Train the decision tree model
tree_model = DecisionTreeClassifier(max_depth=10)
tree_model.fit(X_train, y_train)

# Evaluate the model on the validation set
y_pred_val = tree_model.predict(X_val)
print("Validation Accuracy:", accuracy_score(y_val, y_pred_val))
# Out:
# Validation Accuracy: 0.7600671140939598

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# Initialize the RandomForest model
rf_model = RandomForestClassifier(n_estimators=100, max_depth=100, random_state=42)

# Train the model
rf_model.fit(X_train, y_train)

# Evaluate the model using the validation set
y_pred_val = rf_model.predict(X_val)
print("Validation Accuracy:", accuracy_score(y_val, y_pred_val))
# Out:
# Validation Accuracy: 0.7701342281879194

# %% [markdown]
# ## SVM

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

# Assuming y_train and y_val are one-hot encoded, with shape (number of samples, number of categories)
y_train = np.argmax(y_train, axis=1)
y_val = np.argmax(y_val, axis=1)

# Initialize and apply normalization
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled = scaler.transform(X_val)

# Initialize the SVM model
svm_model = SVC(kernel='rbf', C=1.0, gamma='auto', max_iter=1000)

# Train the SVM model
svm_model.fit(X_train_scaled, y_train)

# Evaluate the SVM model on the validation set
y_pred_val = svm_model.predict(X_val_scaled)
print("Validation Accuracy:", accuracy_score(y_val, y_pred_val))
# Out:
# Validation Accuracy: 0.9379194630872483

# %% [markdown]
# ## MLP Baseline Model for Multi-class Task

# %%
num_classes = 16
input_shape = (28, 28)
baseline_categorical = tf.keras.models.Sequential([
    tf.keras.Input(shape=input_shape),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(num_classes, activation='softmax')
])

# %%
baseline_categorical.compile(loss='categorical_crossentropy',
                        optimizer=tf.keras.optimizers.Adam(),
                        metrics=['accuracy'])

# %%
epochs = 50
history_baseline_categorical = baseline_categorical.fit(
    train_generator,
    validation_data=val_generator,
    epochs=epochs
)
# Out:
# Epoch 1/50
# /Users/tianbai/anaconda3/envs/DL/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:120: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.3652 - loss: 2.1760 - val_accuracy: 0.7483 - val_loss: 1.0620
# Epoch 2/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.7528 - loss: 0.9817 - val_accuracy: 0.8171 - val_loss: 0.6900
# Epoch 3/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.8394 - loss: 0.6505 - val_accuracy: 0.8792 - val_loss: 0.5184
# Epoch 4/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.8940 - loss: 0.5003 - val_accuracy: 0.8993 - val_loss: 0.4515
# Epoch 5/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9121 - loss: 0.4130 - val_accuracy: 0.9362 - val_loss: 0.3608
# Epoch 6/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9267 - loss: 0.3617 - val_accuracy: 0.9295 - val_loss: 0.3472
# Epoch 7/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9273 - loss: 0.3234 - val_accuracy: 0.9413 - val_loss: 0.3026
# Epoch 8/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9482 - loss: 0.2486 - val_accuracy: 0.9295 - val_loss: 0.2899
# Epoch 9/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9554 - loss: 0.2238 - val_accuracy: 0.9480 - val_loss: 0.2503
# Epoch 10/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9620 - loss: 0.1985 - val_accuracy: 0.9362 - val_loss: 0.2722
# Epoch 11/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9557 - loss: 0.1999 - val_accuracy: 0.9379 - val_loss: 0.2457
# Epoch 12/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9655 - loss: 0.1753 - val_accuracy: 0.9362 - val_loss: 0.2661
# Epoch 13/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9636 - loss: 0.1718 - val_accuracy: 0.9430 - val_loss: 0.2296
# Epoch 14/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9752 - loss: 0.1369 - val_accuracy: 0.9547 - val_loss: 0.2013
# Epoch 15/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9689 - loss: 0.1554 - val_accuracy: 0.9262 - val_loss: 0.2535
# Epoch 16/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9656 - loss: 0.1579 - val_accuracy: 0.9530 - val_loss: 0.1932
# Epoch 17/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9765 - loss: 0.1098 - val_accuracy: 0.9581 - val_loss: 0.1845
# Epoch 18/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9753 - loss: 0.1162 - val_accuracy: 0.9564 - val_loss: 0.2000
# Epoch 19/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9796 - loss: 0.0940 - val_accuracy: 0.9497 - val_loss: 0.1856
# Epoch 20/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9899 - loss: 0.0705 - val_accuracy: 0.9614 - val_loss: 0.1643
# Epoch 21/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9851 - loss: 0.0881 - val_accuracy: 0.9564 - val_loss: 0.1688
# Epoch 22/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9906 - loss: 0.0690 - val_accuracy: 0.9497 - val_loss: 0.1966
# Epoch 23/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9857 - loss: 0.0679 - val_accuracy: 0.9597 - val_loss: 0.1688
# Epoch 24/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9899 - loss: 0.0687 - val_accuracy: 0.9581 - val_loss: 0.1714
# Epoch 25/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9902 - loss: 0.0485 - val_accuracy: 0.9614 - val_loss: 0.1664
# Epoch 26/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9951 - loss: 0.0450 - val_accuracy: 0.9614 - val_loss: 0.1622
# Epoch 27/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9952 - loss: 0.0430 - val_accuracy: 0.9614 - val_loss: 0.1760
# Epoch 28/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9954 - loss: 0.0385 - val_accuracy: 0.9614 - val_loss: 0.1583
# Epoch 29/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9932 - loss: 0.0440 - val_accuracy: 0.9597 - val_loss: 0.1654
# Epoch 30/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9923 - loss: 0.0427 - val_accuracy: 0.9648 - val_loss: 0.1575
# Epoch 31/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9851 - loss: 0.0551 - val_accuracy: 0.9530 - val_loss: 0.1832
# Epoch 32/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9937 - loss: 0.0387 - val_accuracy: 0.9480 - val_loss: 0.1758
# Epoch 33/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9943 - loss: 0.0372 - val_accuracy: 0.9614 - val_loss: 0.1514
# Epoch 34/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9990 - loss: 0.0213 - val_accuracy: 0.9547 - val_loss: 0.1645
# Epoch 35/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9989 - loss: 0.0236 - val_accuracy: 0.9698 - val_loss: 0.1479
# Epoch 36/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9972 - loss: 0.0266 - val_accuracy: 0.9446 - val_loss: 0.2082
# Epoch 37/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9916 - loss: 0.0373 - val_accuracy: 0.9648 - val_loss: 0.1483
# Epoch 38/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9954 - loss: 0.0323 - val_accuracy: 0.9581 - val_loss: 0.1594
# Epoch 39/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9999 - loss: 0.0175 - val_accuracy: 0.9581 - val_loss: 0.1422
# Epoch 40/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9992 - loss: 0.0170 - val_accuracy: 0.9597 - val_loss: 0.1631
# Epoch 41/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9994 - loss: 0.0171 - val_accuracy: 0.9614 - val_loss: 0.1514
# Epoch 42/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9921 - loss: 0.0337 - val_accuracy: 0.9564 - val_loss: 0.1709
# Epoch 43/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9938 - loss: 0.0265 - val_accuracy: 0.9681 - val_loss: 0.1400
# Epoch 44/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9988 - loss: 0.0163 - val_accuracy: 0.9648 - val_loss: 0.1440
# Epoch 45/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9997 - loss: 0.0136 - val_accuracy: 0.9648 - val_loss: 0.1475
# Epoch 46/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9989 - loss: 0.0127 - val_accuracy: 0.9631 - val_loss: 0.1511
# Epoch 47/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 0.0116 - val_accuracy: 0.9664 - val_loss: 0.1496
# Epoch 48/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 0.0088 - val_accuracy: 0.9648 - val_loss: 0.1472
# Epoch 49/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 0.0083 - val_accuracy: 0.9664 - val_loss: 0.1491
# Epoch 50/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 0.0087 - val_accuracy: 0.9681 - val_loss: 0.1473

# %%
import matplotlib.pyplot as plt

def plot_training_history(history):
    """
    Plot training and validation metrics based on the History object from a Keras model.

    Parameters:
    - history: History object returned from the fit method.
    """
    epochs_range = range(1, len(history.history['accuracy']) + 1)  # Assuming there's at least the 'accuracy' metric
    metrics = [key for key in history.history.keys() if not key.startswith("val_")]  # Retrieve all non-validation metrics
    _, axes = plt.subplots(1, len(metrics), figsize=(20, 4))  # Dynamically adjust the number of subplots based on the number of metrics

    for idx, metric in enumerate(metrics):
        # Plot the training and validation curve for each metric in each subplot
        axes[idx].plot(epochs_range, history.history[metric], label=f'Training {metric.capitalize()}')
        axes[idx].plot(epochs_range, history.history[f"val_{metric}"], label=f'Validation {metric.capitalize()}')
        axes[idx].legend()
        axes[idx].set_title(f'Training and Validation {metric.capitalize()}')
        axes[idx].set_xlabel('Epoch')
        axes[idx].set_ylabel(metric.capitalize())
    
    plt.tight_layout()
    plt.show()

# Assuming history_baseline_categorical is the training history object of your MLP model
# Call the function to plot
plot_training_history(history_baseline_categorical)

# %% [markdown]
# ## Modify images to make classify more difficult

# %%
train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255,
    rotation_range=30,  # Rotation range (degrees), adjustable range, e.g., 20-40
    width_shift_range=0.1,  # Horizontal shift range
    height_shift_range=0.1,  # Vertical shift range
    shear_range=0.1,  # Shearing range
    zoom_range=0.1,  # Zoom range
    horizontal_flip=True,  # Horizontal flip
)
val_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)
test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_dataframe(
    dataframe=train_df,
    x_col='ImagePath',
    y_col='Label',
    color_mode='grayscale',
    target_size=(28, 28),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=True
)

val_generator = val_datagen.flow_from_dataframe(
    dataframe=validation_df,
    x_col='ImagePath',
    y_col='Label',
    color_mode='grayscale',
    target_size=(28, 28),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)

test_generator = test_datagen.flow_from_dataframe(
    dataframe=test_df,
    x_col='ImagePath',
    y_col='Label',
    color_mode='grayscale',
    target_size=(28, 28),
    batch_size=batch_size,
    class_mode='categorical',  
    shuffle=False
)
# Out:
# Found 2358 validated image filenames belonging to 16 classes.
# Found 596 validated image filenames belonging to 16 classes.
# Found 745 validated image filenames belonging to 16 classes.

# %% [markdown]
# ## SVM Model with modified dataset

# %%
import numpy as np
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

def get_data_from_generator(generator):
    batches = []
    labels = []
    # Iterate over the generator to collect data and labels
    for batch, label in generator:
        batches.append(batch)
        labels.append(label)
        if len(batches) >= len(generator):
            break  # Ensure there is no infinite iteration
    return np.vstack(batches), np.vstack(labels)

X_train, y_train = get_data_from_generator(train_generator)
X_val, y_val = get_data_from_generator(val_generator)
X_test, y_test = get_data_from_generator(test_generator)

# Reshape the data to fit the input requirements of StandardScaler
X_train = X_train.reshape(X_train.shape[0], -1)
X_val = X_val.reshape(X_val.shape[0], -1)
X_test = X_test.reshape(X_test.shape[0], -1)

# Assuming y_train and y_val are one-hot encoded, with shape (number of samples, number of classes)
y_train = np.argmax(y_train, axis=1)
y_val = np.argmax(y_val, axis=1)

# Initialize and apply standardization
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled = scaler.transform(X_val)

# Initialize SVM model
svm_model = SVC(kernel='rbf', C=1.0, gamma='auto', max_iter=1000)

# Train the SVM model
svm_model.fit(X_train_scaled, y_train)

# Evaluate the SVM model on the validation set
y_pred_val = svm_model.predict(X_val_scaled)
print("Validation Accuracy:", accuracy_score(y_val, y_pred_val))
# Out:
# Validation Accuracy: 0.697986577181208

# %%
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

report = classification_report(y_val, y_pred_val, target_names=label_names, zero_division=1)
print(report)

cm = confusion_matrix(y_val, y_pred_val)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt="d", cmap='Blues', xticklabels=label_names, yticklabels=label_names)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()
# Out:
#                   precision    recall  f1-score   support
#
#          bicycle       0.67      0.70      0.68        46
#         continue       0.86      0.78      0.82        32
#         crossing       1.00      0.00      0.00        16
#          giveway       0.83      0.81      0.82        37
#          laneend       1.00      0.58      0.73        19
#   limitedtraffic       0.88      0.35      0.50        20
#          noentry       0.82      0.90      0.86        60
#        noparking       0.45      0.67      0.54        39
#          parking       0.82      0.84      0.83        44
#       rightofway       0.81      0.76      0.78        45
#       roundabout       1.00      0.00      0.00        16
#            speed       0.56      0.61      0.58        51
#             stop       1.00      0.00      0.00         7
# trafficdirective       0.56      0.59      0.58        32
#  traveldirection       1.00      0.05      0.10        20
#          warning       0.67      0.97      0.79       112
#
#         accuracy                           0.70       596
#        macro avg       0.81      0.54      0.54       596
#     weighted avg       0.75      0.70      0.66       596

# %% [markdown]
# ## MLP Model with modified dataset

# %%
num_classes = 16
input_shape = (28, 28)
baseline_categorical = tf.keras.models.Sequential([
    tf.keras.Input(shape=input_shape),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(num_classes, activation='softmax')
])

# %%
baseline_categorical.compile(loss='binary_crossentropy',
                        optimizer=tf.keras.optimizers.Adam(),
                        metrics=['accuracy'])

# %%
epochs = 50
history_baseline_categorical = baseline_categorical.fit(
    train_generator,
    validation_data=val_generator,
    epochs=epochs
)
# Out:
# Epoch 1/50
# /Users/tianbai/anaconda3/envs/DL/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:120: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.1800 - loss: 0.3141 - val_accuracy: 0.3725 - val_loss: 0.2052
# Epoch 2/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.3249 - loss: 0.2123 - val_accuracy: 0.3423 - val_loss: 0.1878
# Epoch 3/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.3727 - loss: 0.1963 - val_accuracy: 0.5654 - val_loss: 0.1635
# Epoch 4/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.4397 - loss: 0.1868 - val_accuracy: 0.6208 - val_loss: 0.1575
# Epoch 5/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.4479 - loss: 0.1810 - val_accuracy: 0.5923 - val_loss: 0.1485
# Epoch 6/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.4693 - loss: 0.1751 - val_accuracy: 0.6023 - val_loss: 0.1385
# Epoch 7/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.4581 - loss: 0.1713 - val_accuracy: 0.6393 - val_loss: 0.1331
# Epoch 8/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.4994 - loss: 0.1642 - val_accuracy: 0.6594 - val_loss: 0.1302
# Epoch 9/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.4956 - loss: 0.1621 - val_accuracy: 0.6376 - val_loss: 0.1288
# Epoch 10/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.5057 - loss: 0.1586 - val_accuracy: 0.6628 - val_loss: 0.1217
# Epoch 11/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.5184 - loss: 0.1579 - val_accuracy: 0.6862 - val_loss: 0.1186
# Epoch 12/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.5341 - loss: 0.1516 - val_accuracy: 0.7164 - val_loss: 0.1140
# Epoch 13/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.5188 - loss: 0.1543 - val_accuracy: 0.7064 - val_loss: 0.1156
# Epoch 14/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.5658 - loss: 0.1465 - val_accuracy: 0.6997 - val_loss: 0.1120
# Epoch 15/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.5560 - loss: 0.1461 - val_accuracy: 0.7013 - val_loss: 0.1085
# Epoch 16/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.5633 - loss: 0.1432 - val_accuracy: 0.7198 - val_loss: 0.1071
# Epoch 17/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.5759 - loss: 0.1403 - val_accuracy: 0.7064 - val_loss: 0.1051
# Epoch 18/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.5833 - loss: 0.1374 - val_accuracy: 0.7081 - val_loss: 0.1041
# Epoch 19/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.5817 - loss: 0.1383 - val_accuracy: 0.7299 - val_loss: 0.1034
# Epoch 20/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.5791 - loss: 0.1410 - val_accuracy: 0.7349 - val_loss: 0.0981
# Epoch 21/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.5959 - loss: 0.1333 - val_accuracy: 0.7450 - val_loss: 0.0960
# Epoch 22/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.5929 - loss: 0.1324 - val_accuracy: 0.7701 - val_loss: 0.0931
# Epoch 23/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6134 - loss: 0.1291 - val_accuracy: 0.7315 - val_loss: 0.0962
# Epoch 24/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6000 - loss: 0.1302 - val_accuracy: 0.7718 - val_loss: 0.0926
# Epoch 25/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6054 - loss: 0.1286 - val_accuracy: 0.7517 - val_loss: 0.0941
# Epoch 26/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6124 - loss: 0.1257 - val_accuracy: 0.7752 - val_loss: 0.0913
# Epoch 27/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6406 - loss: 0.1225 - val_accuracy: 0.7685 - val_loss: 0.0892
# Epoch 28/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.6387 - loss: 0.1216 - val_accuracy: 0.7617 - val_loss: 0.0902
# Epoch 29/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6045 - loss: 0.1262 - val_accuracy: 0.7550 - val_loss: 0.0931
# Epoch 30/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6421 - loss: 0.1204 - val_accuracy: 0.7718 - val_loss: 0.0847
# Epoch 31/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6262 - loss: 0.1197 - val_accuracy: 0.7718 - val_loss: 0.0859
# Epoch 32/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6299 - loss: 0.1191 - val_accuracy: 0.7584 - val_loss: 0.0878
# Epoch 33/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6402 - loss: 0.1176 - val_accuracy: 0.8121 - val_loss: 0.0823
# Epoch 34/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6570 - loss: 0.1166 - val_accuracy: 0.7785 - val_loss: 0.0837
# Epoch 35/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6588 - loss: 0.1129 - val_accuracy: 0.7836 - val_loss: 0.0836
# Epoch 36/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6620 - loss: 0.1153 - val_accuracy: 0.7919 - val_loss: 0.0830
# Epoch 37/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6698 - loss: 0.1145 - val_accuracy: 0.7953 - val_loss: 0.0795
# Epoch 38/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6659 - loss: 0.1147 - val_accuracy: 0.7987 - val_loss: 0.0782
# Epoch 39/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6711 - loss: 0.1126 - val_accuracy: 0.7869 - val_loss: 0.0811
# Epoch 40/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6689 - loss: 0.1121 - val_accuracy: 0.8020 - val_loss: 0.0784
# Epoch 41/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.6482 - loss: 0.1124 - val_accuracy: 0.8020 - val_loss: 0.0768
# Epoch 42/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6662 - loss: 0.1091 - val_accuracy: 0.8070 - val_loss: 0.0790
# Epoch 43/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6870 - loss: 0.1068 - val_accuracy: 0.8037 - val_loss: 0.0765
# Epoch 44/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7015 - loss: 0.1044 - val_accuracy: 0.7987 - val_loss: 0.0763
# Epoch 45/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.6893 - loss: 0.1057 - val_accuracy: 0.8037 - val_loss: 0.0762
# Epoch 46/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6730 - loss: 0.1080 - val_accuracy: 0.7836 - val_loss: 0.0775
# Epoch 47/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7050 - loss: 0.1022 - val_accuracy: 0.8070 - val_loss: 0.0743
# Epoch 48/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6606 - loss: 0.1081 - val_accuracy: 0.8154 - val_loss: 0.0716
# Epoch 49/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6946 - loss: 0.1049 - val_accuracy: 0.8205 - val_loss: 0.0739
# Epoch 50/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6994 - loss: 0.1035 - val_accuracy: 0.8020 - val_loss: 0.0753

# %%
import matplotlib.pyplot as plt

def plot_training_history(history):
    """
    根据Keras模型的History对象绘制训练和验证的指标。

    参数:
    - history: 从fit方法返回的History对象。
    """
    epochs_range = range(1, len(history.history['accuracy']) + 1) 
    metrics = [key for key in history.history.keys() if not key.startswith("val_")]  
    _, axes = plt.subplots(1, len(metrics), figsize=(20, 4))  

    for idx, metric in enumerate(metrics):
        axes[idx].plot(epochs_range, history.history[metric], label=f'Training {metric.capitalize()}')
        axes[idx].plot(epochs_range, history.history[f"val_{metric}"], label=f'Validation {metric.capitalize()}')
        axes[idx].legend()
        axes[idx].set_title(f'Training and Validation {metric.capitalize()}')
        axes[idx].set_xlabel('Epoch')
        axes[idx].set_ylabel(metric.capitalize())
    
    plt.tight_layout()
    plt.show()

plot_training_history(history_baseline_categorical)

# %%
y_pred_val_prob = baseline_categorical.predict(val_generator)
y_pred_val = np.argmax(y_pred_val_prob, axis=1)

from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

report = classification_report(val_generator.classes, y_pred_val, target_names=label_names)
print(report)

cm = confusion_matrix(val_generator.classes, y_pred_val)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt="d", cmap='Blues', xticklabels=label_names, yticklabels=label_names)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
#                   precision    recall  f1-score   support
#
#          bicycle       0.93      0.89      0.91        46
#         continue       0.78      1.00      0.88        32
#         crossing       1.00      0.19      0.32        16
#          giveway       0.94      0.92      0.93        37
#          laneend       0.89      0.84      0.86        19
#   limitedtraffic       0.67      0.70      0.68        20
#          noentry       0.83      0.95      0.88        60
#        noparking       0.75      0.77      0.76        39
#          parking       0.91      0.91      0.91        44
#       rightofway       0.75      0.91      0.82        45
#       roundabout       0.89      0.50      0.64        16
#            speed       0.88      0.55      0.67        51
#             stop       1.00      0.29      0.44         7
# trafficdirective       0.59      0.59      0.59        32
#  traveldirection       0.88      0.35      0.50        20
#          warning       0.75      0.95      0.83       112
#
#         accuracy                           0.80       596
#        macro avg       0.84      0.71      0.73       596
#     weighted avg       0.82      0.80      0.79       596

# %% [markdown]
# ## CNN Model for Multi Class

# %%
from tensorflow.keras import models, layers

num_classes = 16  # Adjust the number of classes according to your task

cnn_model = models.Sequential([
    layers.Input(shape=(28, 28, 1)),  # Input for grayscale images, 1 channel
    layers.Conv2D(32, (3, 3), padding='same'),  # First convolutional layer, 32 filters
    layers.BatchNormalization(),  # Adding batch normalization
    layers.Activation('relu'),  # Activation layer
    layers.MaxPooling2D((2, 2)),  # Max pooling
    layers.Conv2D(64, (3, 3), padding='same'),  # Second convolutional layer, 64 filters
    layers.BatchNormalization(),  # Adding batch normalization
    layers.Activation('relu'),  # Activation layer
    layers.MaxPooling2D((2, 2)),  # Max pooling
    layers.Conv2D(128, (3, 3), padding='same'),  # Third convolutional layer, 128 filters
    layers.BatchNormalization(),  # Adding batch normalization
    layers.Activation('relu'),  # Activation layer
    layers.MaxPooling2D((2, 2)),  # Max pooling
    layers.Flatten(),  # Flatten the convolutional result
    layers.Dense(512),  # Fully connected layer
    layers.BatchNormalization(),  # Adding batch normalization
    layers.Activation('relu'),  # Activation layer
    layers.Dense(num_classes, activation='softmax')  # Output layer, using softmax activation
])

from tensorflow.keras.callbacks import Callback
import numpy as np

class PerClassAccuracy(Callback):
    def __init__(self, validation_generator, num_classes):
        super().__init__()
        self.validation_generator = validation_generator
        self.num_classes = num_classes
        self.history = {'val_accuracy_per_class': []}

    def on_epoch_end(self, epoch, logs=None):
        val_preds = self.model.predict(self.validation_generator)
        val_classes = np.argmax(val_preds, axis=1)
        true_classes = self.validation_generator.classes
        correct_preds = np.zeros(self.num_classes)
        total_preds = np.zeros(self.num_classes)

        for i in range(self.num_classes):
            for true, pred in zip(true_classes, val_classes):
                if true == i:
                    total_preds[i] += 1
                    if true == pred:
                        correct_preds[i] += 1

        accuracy_per_class = correct_preds / total_preds
        self.history['val_accuracy_per_class'].append(accuracy_per_class)

# Usage
num_classes = 16
validation_data = val_generator  # Assume val_generator is already defined
per_class_accuracy_callback = PerClassAccuracy(validation_data, num_classes)

cnn_model.compile(
    loss='categorical_crossentropy',  # Using categorical crossentropy loss
    optimizer=tf.keras.optimizers.Adam(),  # Adam optimizer
    metrics=['accuracy']  # Using accuracy as metric
)

# %%
epochs = 50
history_cnn = cnn_model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=epochs,
    callbacks=[per_class_accuracy_callback],
    verbose=1
)
# Out:
# Epoch 1/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 12s 225ms/step - accuracy: 0.4652 - loss: 1.8424 - val_accuracy: 0.0654 - val_loss: 2.6184
# Epoch 2/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.8488 - loss: 0.5285 - val_accuracy: 0.1275 - val_loss: 2.9060
# Epoch 3/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.8891 - loss: 0.3686 - val_accuracy: 0.1493 - val_loss: 3.2452
# Epoch 4/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - accuracy: 0.9145 - loss: 0.2661 - val_accuracy: 0.2097 - val_loss: 3.0020
# Epoch 5/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.9337 - loss: 0.2300 - val_accuracy: 0.2953 - val_loss: 2.8272
# Epoch 6/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - accuracy: 0.9427 - loss: 0.1784 - val_accuracy: 0.4664 - val_loss: 1.9730
# Epoch 7/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - accuracy: 0.9443 - loss: 0.1837 - val_accuracy: 0.5973 - val_loss: 1.4714
# Epoch 8/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - accuracy: 0.9534 - loss: 0.1588 - val_accuracy: 0.6141 - val_loss: 1.3392
# Epoch 9/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - accuracy: 0.9652 - loss: 0.1209 - val_accuracy: 0.7232 - val_loss: 0.8788
# Epoch 10/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - accuracy: 0.9669 - loss: 0.1052 - val_accuracy: 0.7550 - val_loss: 0.7154
# Epoch 11/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.9721 - loss: 0.1007 - val_accuracy: 0.9094 - val_loss: 0.2838
# Epoch 12/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - accuracy: 0.9767 - loss: 0.0826 - val_accuracy: 0.9077 - val_loss: 0.3021
# Epoch 13/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - accuracy: 0.9709 - loss: 0.0889 - val_accuracy: 0.9195 - val_loss: 0.2173
# Epoch 14/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - accuracy: 0.9788 - loss: 0.0777 - val_accuracy: 0.9631 - val_loss: 0.1069
# Epoch 15/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - accuracy: 0.9757 - loss: 0.0766 - val_accuracy: 0.9849 - val_loss: 0.0549
# Epoch 16/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - accuracy: 0.9710 - loss: 0.0891 - val_accuracy: 0.9748 - val_loss: 0.0910
# Epoch 17/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - accuracy: 0.9795 - loss: 0.0724 - val_accuracy: 0.9832 - val_loss: 0.0527
# Epoch 18/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - accuracy: 0.9795 - loss: 0.0621 - val_accuracy: 0.9866 - val_loss: 0.0409
# Epoch 19/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - accuracy: 0.9668 - loss: 0.0818 - val_accuracy: 0.9866 - val_loss: 0.0471
# Epoch 20/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - accuracy: 0.9762 - loss: 0.0706 - val_accuracy: 0.9849 - val_loss: 0.0489
# Epoch 21/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - accuracy: 0.9805 - loss: 0.0635 - val_accuracy: 0.9832 - val_loss: 0.0495
# Epoch 22/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - accuracy: 0.9908 - loss: 0.0386 - val_accuracy: 0.9849 - val_loss: 0.0522
# Epoch 23/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - accuracy: 0.9867 - loss: 0.0557 - val_accuracy: 0.9849 - val_loss: 0.0502
# Epoch 24/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - accuracy: 0.9881 - loss: 0.0409 - val_accuracy: 0.9866 - val_loss: 0.0415
# Epoch 25/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - accuracy: 0.9861 - loss: 0.0444 - val_accuracy: 0.9815 - val_loss: 0.0486
# Epoch 26/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - accuracy: 0.9833 - loss: 0.0595 - val_accuracy: 0.9815 - val_loss: 0.0641
# Epoch 27/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - accuracy: 0.9835 - loss: 0.0557 - val_accuracy: 0.9832 - val_loss: 0.0661
# Epoch 28/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - accuracy: 0.9830 - loss: 0.0476 - val_accuracy: 0.9933 - val_loss: 0.0304
# Epoch 29/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - accuracy: 0.9900 - loss: 0.0315 - val_accuracy: 0.9866 - val_loss: 0.0388
# Epoch 30/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - accuracy: 0.9889 - loss: 0.0344 - val_accuracy: 0.9866 - val_loss: 0.0346
# Epoch 31/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - accuracy: 0.9889 - loss: 0.0419 - val_accuracy: 0.9681 - val_loss: 0.0973
# Epoch 32/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - accuracy: 0.9872 - loss: 0.0411 - val_accuracy: 0.9664 - val_loss: 0.0979
# Epoch 33/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - accuracy: 0.9894 - loss: 0.0430 - val_accuracy: 0.9832 - val_loss: 0.0467
# Epoch 34/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - accuracy: 0.9887 - loss: 0.0378 - val_accuracy: 0.9832 - val_loss: 0.0294
# Epoch 35/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - accuracy: 0.9894 - loss: 0.0403 - val_accuracy: 0.9849 - val_loss: 0.0380
# Epoch 36/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - accuracy: 0.9873 - loss: 0.0389 - val_accuracy: 0.9681 - val_loss: 0.1129
# Epoch 37/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - accuracy: 0.9841 - loss: 0.0514 - val_accuracy: 0.9597 - val_loss: 0.1177
# Epoch 38/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - accuracy: 0.9897 - loss: 0.0381 - val_accuracy: 0.9799 - val_loss: 0.0753
# Epoch 39/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - accuracy: 0.9877 - loss: 0.0411 - val_accuracy: 0.9883 - val_loss: 0.0489
# Epoch 40/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - accuracy: 0.9896 - loss: 0.0261 - val_accuracy: 0.9899 - val_loss: 0.0376
# Epoch 41/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - accuracy: 0.9843 - loss: 0.0382 - val_accuracy: 0.9765 - val_loss: 0.0529
# Epoch 42/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - accuracy: 0.9907 - loss: 0.0285 - val_accuracy: 0.9899 - val_loss: 0.0365
# Epoch 43/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - accuracy: 0.9916 - loss: 0.0280 - val_accuracy: 0.9815 - val_loss: 0.0414
# Epoch 44/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - accuracy: 0.9927 - loss: 0.0245 - val_accuracy: 0.9681 - val_loss: 0.1002
# Epoch 45/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - accuracy: 0.9911 - loss: 0.0294 - val_accuracy: 0.9681 - val_loss: 0.1102
# Epoch 46/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - accuracy: 0.9932 - loss: 0.0255 - val_accuracy: 0.9765 - val_loss: 0.0979
# Epoch 47/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - accuracy: 0.9924 - loss: 0.0248 - val_accuracy: 0.9815 - val_loss: 0.0977
# Epoch 48/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - accuracy: 0.9938 - loss: 0.0242 - val_accuracy: 0.9782 - val_loss: 0.0715
# Epoch 49/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - accuracy: 0.9905 - loss: 0.0338 - val_accuracy: 0.9748 - val_loss: 0.0881
# Epoch 50/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - accuracy: 0.9874 - loss: 0.0417 - val_accuracy: 0.9883 - val_loss: 0.0327

# %%
import matplotlib.pyplot as plt

def plot_training_history(history):

    epochs_range = range(1, len(history.history['accuracy']) + 1)  
    metrics = [key for key in history.history.keys() if not key.startswith("val_")]  
    _, axes = plt.subplots(1, len(metrics), figsize=(20, 4))  

    for idx, metric in enumerate(metrics):
        axes[idx].plot(epochs_range, history.history[metric], label=f'Training {metric.capitalize()}')
        axes[idx].plot(epochs_range, history.history[f"val_{metric}"], label=f'Validation {metric.capitalize()}')
        axes[idx].legend()
        axes[idx].set_title(f'Training and Validation {metric.capitalize()}')
        axes[idx].set_xlabel('Epoch')
        axes[idx].set_ylabel(metric.capitalize())
    
    plt.tight_layout()
    plt.show()

plot_training_history(history_cnn)

# %%
import numpy as np

if y_pred_val_prob.ndim > 1:
    y_pred_val = np.argmax(y_pred_val_prob, axis=1)
else:
    y_pred_val = y_pred_val_prob  

y_val = val_generator.labels

from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

report = classification_report(y_val, y_pred_val, target_names=label_names)
print(report)

def plot_per_class_training_history(per_class_history, label_names):
    num_classes = len(label_names)  # 确定类别数量
    epochs_range = range(1, len(per_class_history['val_accuracy_per_class']) + 1)
    plt.figure(figsize=(20, 40))  # 根据类别数量调整图形尺寸

    for i in range(num_classes):
        plt.subplot(num_classes, 1, i+1)
        class_accuracy = [acc[i] for acc in per_class_history['val_accuracy_per_class']]
        plt.plot(epochs_range, class_accuracy, label=f'Validation Accuracy for {label_names[i]}')
        plt.legend()
        plt.title(label_names[i])  # 使用类别名称作为标题
        plt.xlabel('Epoch')
        plt.ylabel('Accuracy')

    plt.tight_layout()
    plt.show()

plot_per_class_training_history(per_class_accuracy_callback.history, label_names)
# Out:
#                   precision    recall  f1-score   support
#
#          bicycle       0.93      0.89      0.91        46
#         continue       0.78      1.00      0.88        32
#         crossing       1.00      0.19      0.32        16
#          giveway       0.94      0.92      0.93        37
#          laneend       0.89      0.84      0.86        19
#   limitedtraffic       0.67      0.70      0.68        20
#          noentry       0.83      0.95      0.88        60
#        noparking       0.75      0.77      0.76        39
#          parking       0.91      0.91      0.91        44
#       rightofway       0.75      0.91      0.82        45
#       roundabout       0.89      0.50      0.64        16
#            speed       0.88      0.55      0.67        51
#             stop       1.00      0.29      0.44         7
# trafficdirective       0.59      0.59      0.59        32
#  traveldirection       0.88      0.35      0.50        20
#          warning       0.75      0.95      0.83       112
#
#         accuracy                           0.80       596
#        macro avg       0.84      0.71      0.73       596
#     weighted avg       0.82      0.80      0.79       596
