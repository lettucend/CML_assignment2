# %%
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image, UnidentifiedImageError
from PIL import Image, ImageOps
from tensorflow.keras import layers, models
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
import tensorflow as tf
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.0' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# C:\Users\HP\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:62: UserWarning: Pandas requires version '1.3.4' or newer of 'bottleneck' (version '1.3.2' currently installed).
#   from pandas.core import (
# C:\Users\HP\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
import os
from PIL import Image, UnidentifiedImageError

# Root directory of the images
root_dir = 'trafficsigns_dataset'  # Replace with the actual path

# Nested dictionary to store images categorized by two levels of labels
images_by_label = {}

# Function to traverse the dataset and load images and their labels
def load_images_and_labels(root_dir):
    # Iterate through each subdirectory in the root directory (first level)
    for sub_dir in os.listdir(root_dir):
        sub_dir_path = os.path.join(root_dir, sub_dir)
        
        # Check if the subdirectory is indeed a directory
        if os.path.isdir(sub_dir_path):
            # Initialize the first level label key
            images_by_label[sub_dir] = {}
            
            # Iterate again through the folders within the subdirectory (second level, specific labels)
            for label_dir in os.listdir(sub_dir_path):
                label_dir_path = os.path.join(sub_dir_path, label_dir)
                
                # Check if the second level is also a directory
                if os.path.isdir(label_dir_path):
                    # Initialize the second level label key
                    images_by_label[sub_dir][label_dir] = []
                    
                    # Iterate through all image files in the second level directory
                    for image_filename in os.listdir(label_dir_path):
                        # Ignore .DS_Store files
                        if image_filename == '.DS_Store':
                            continue
                        image_path = os.path.join(label_dir_path, image_filename)
                        try:
                            images_by_label[sub_dir][label_dir].append(image_path)
                        except UnidentifiedImageError:
                            # Print error message if the image cannot be identified
                            print(f"Cannot identify image file '{image_path}'")

# Load images and labels
load_images_and_labels(root_dir)

# Print the number of images for each category
for sub_dir, labels in images_by_label.items():
    for label, images in labels.items():
        print(f"{sub_dir}/{label}: {len(images)} images")
        
label_names = []
for sub_dir in images_by_label:
    for label in images_by_label[sub_dir]:
        if label not in label_names:
            label_names.append(label)

# Sort label names to maintain consistency
label_names.sort()

# Now label_names contains all unique labels, sorted alphabetically
# Out:
# diamond/rightofway: 282 images
# hex/stop: 43 images
# round/bicycle: 285 images
# round/limitedtraffic: 125 images
# round/noentry: 375 images
# round/noparking: 242 images
# round/roundabout: 98 images
# round/speed: 316 images
# round/trafficdirective: 195 images
# round/traveldirection: 124 images
# square/continue: 199 images
# square/crossing: 95 images
# square/laneend: 118 images
# square/parking: 276 images
# triangle/giveway: 231 images
# triangle/warning: 695 images

# %%
def get_image_sizes(root_dir):
    sizes = []
    # Traverse through the directory structure in root_dir
    for subdir, dirs, files in os.walk(root_dir):
        for file in files:
            # Check if the file is a PNG or JPG
            if file.lower().endswith('.png') or file.lower().endswith('.jpg'):
                try:
                    # Open the image file and append its size (width, height)
                    with Image.open(os.path.join(subdir, file)) as img:
                        sizes.append(img.size)
                except (IOError, UnidentifiedImageError):
                    # Continue to the next file if an error occurs
                    continue
    return sizes

# Call the function to get the sizes of all images in the directory
image_sizes = get_image_sizes(root_dir)

# Convert list of sizes to a NumPy array for statistical calculation
sizes_np = np.array(image_sizes)
min_size = sizes_np.min(axis=0)
max_size = sizes_np.max(axis=0)
mean_size = sizes_np.mean(axis=0)
std_dev_size = sizes_np.std(axis=0)
median_size = np.median(sizes_np, axis=0)

# Output the minimum, maximum, mean, standard deviation, and median sizes of the images
min_size, max_size, mean_size, std_dev_size, median_size
# Out:
# (array([28, 28]),
#  array([28, 28]),
#  array([28., 28.]),
#  array([0., 0.]),
#  array([28., 28.]))

# %%
train_data = {}
test_data = {}
validation_data = {}

for first_level, second_level_dict in images_by_label.items():
    train_data[first_level] = {}
    validation_data[first_level] = {}
    test_data[first_level] = {}
    
    for label, image_paths in second_level_dict.items():
        temp_images, test_images = train_test_split(image_paths, test_size=0.2, random_state=42)
        train_images, val_images = train_test_split(temp_images, test_size=0.2, random_state=42)
        
        # Save split data
        train_data[first_level][label] = train_images
        test_data[first_level][label] = test_images
        validation_data[first_level][label] = val_images

# %%
def create_dataframe_for_16_class(data_dict):
    rows = []
    for first_level, second_level_dict in data_dict.items():
        for label, image_paths in second_level_dict.items():
            for path in image_paths:
                rows.append({'ImagePath': path, 'Label': label})
    return pd.DataFrame(rows)

def create_dataframe_for_5_class(data_dict):
    rows = []
    for first_level, second_level_dict in data_dict.items():
        for label, image_paths in second_level_dict.items():
            for path in image_paths:
                rows.append({'ImagePath': path, 'Label': first_level})
    return pd.DataFrame(rows)

train_df = create_dataframe_for_16_class(train_data)
test_df = create_dataframe_for_16_class(test_data)
validation_df = create_dataframe_for_16_class(validation_data)

# %%
batch_size = 64

# %%
# Initialize image data generators with rescaling
train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)
val_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)
test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)

# Create a training data generator from a dataframe
train_generator = train_datagen.flow_from_dataframe(
    dataframe=train_df,
    x_col='ImagePath',          # Column in dataframe that contains the image paths
    y_col='Label',              # Column in dataframe that contains the labels
    color_mode='grayscale',     # Use grayscale images
    target_size=(28, 28),       # Resize images to 28x28 pixels
    batch_size=batch_size,      # Number of images to process in a batch
    class_mode='categorical',   # If it's a multi-class problem
    shuffle=True                # Shuffle the order of the images
)

# Create a validation data generator from a dataframe
val_generator = val_datagen.flow_from_dataframe(
    dataframe=validation_df,
    x_col='ImagePath',          # Column in dataframe that contains the image paths
    y_col='Label',              # Column in dataframe that contains the labels
    color_mode='grayscale',     # Use grayscale images
    target_size=(28, 28),       # Resize images to 28x28 pixels
    batch_size=batch_size,      # Number of images to process in a batch
    class_mode='categorical',   # If it's a multi-class problem
    shuffle=False               # Do not shuffle the images
)

# Create a test data generator from a dataframe
test_generator = test_datagen.flow_from_dataframe(
    dataframe=test_df,
    x_col='ImagePath',          # Column in dataframe that contains the image paths
    y_col='Label',              # Column in dataframe that contains the labels
    color_mode='grayscale',     # Use grayscale images
    target_size=(28, 28),       # Resize images to 28x28 pixels
    batch_size=batch_size,      # Number of images to process in a batch
    class_mode='categorical',   # If it's a multi-class problem
    shuffle=False               # Do not shuffle the images
)
# Out:
# Found 2358 validated image filenames belonging to 16 classes.
# Found 596 validated image filenames belonging to 16 classes.
# Found 745 validated image filenames belonging to 16 classes.

# %%
import numpy as np

def get_data_from_generator(generator):
    batches = []
    labels = []
    # Iterate over the generator to collect data and labels
    for batch, label in generator:
        batches.append(batch)
        labels.append(label)
        if len(batches) >= len(generator):
            break  # Ensure not to iterate infinitely
    return np.vstack(batches), np.vstack(labels)

# Get training, validation, and test data and labels
X_train, y_train = get_data_from_generator(train_generator)
X_val, y_val = get_data_from_generator(val_generator)
X_test, y_test = get_data_from_generator(test_generator)

# %%
# Assume the original shape of X_train and X_val is [number of samples, 28, 28, 1] - as extracted from an image generator

# Reshape X_train and X_val into two-dimensional arrays, one row per image
X_train = X_train.reshape(X_train.shape[0], -1)  # -1 calculates the necessary size based on the remaining dimensions
X_val = X_val.reshape(X_val.shape[0], -1)

# If using get_data_from_generator function to extract data, make sure to adjust the function or data before reshaping
# For example, ensure data is correctly extracted and transformed from the generator
X_train, y_train = get_data_from_generator(train_generator)
X_train = X_train.reshape(X_train.shape[0], -1)

X_val, y_val = get_data_from_generator(val_generator)
X_val = X_val.reshape(X_val.shape[0], -1)

# Train the decision tree model
tree_model = DecisionTreeClassifier(max_depth=10)
tree_model.fit(X_train, y_train)

# Evaluate the model on the validation set
y_pred_val = tree_model.predict(X_val)
print("Validation Accuracy:", accuracy_score(y_val, y_pred_val))
# Out:
# Validation Accuracy: 0.7416107382550335

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# Initialize the RandomForest model
rf_model = RandomForestClassifier(n_estimators=100, max_depth=100, random_state=42)

# Train the model
rf_model.fit(X_train, y_train)

# Evaluate the model using the validation set
y_pred_val = rf_model.predict(X_val)
print("Validation Accuracy:", accuracy_score(y_val, y_pred_val))
# Out:
# Validation Accuracy: 0.7533557046979866

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

# Assuming y_train and y_val are one-hot encoded, with shape (number of samples, number of categories)
y_train = np.argmax(y_train, axis=1)
y_val = np.argmax(y_val, axis=1)

# Initialize and apply normalization
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled = scaler.transform(X_val)

# Initialize the SVM model
svm_model = SVC(kernel='rbf', C=1.0, gamma='auto', max_iter=1000)

# Train the SVM model
svm_model.fit(X_train_scaled, y_train)

# Evaluate the SVM model on the validation set
y_pred_val = svm_model.predict(X_val_scaled)
print("Validation Accuracy:", accuracy_score(y_val, y_pred_val))
# Out:
# Validation Accuracy: 0.9211409395973155

# %%
num_classes = 16
input_shape = (28, 28)
baseline_categorical = tf.keras.models.Sequential([
    tf.keras.Input(shape=input_shape),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(num_classes, activation='softmax')
])

# %%
baseline_categorical.compile(loss='categorical_crossentropy',
                        optimizer=tf.keras.optimizers.Adam(),
                        metrics=['accuracy'])

# %%
epochs = 50
history_baseline_categorical = baseline_categorical.fit(
    train_generator,
    validation_data=val_generator,
    epochs=epochs
)
# Out:
# Epoch 1/50
# 37/37 [==============================] - 4s 89ms/step - loss: 1.7171 - accuracy: 0.5530 - val_loss: 1.0871 - val_accuracy: 0.7366
# Epoch 2/50
# 37/37 [==============================] - 3s 78ms/step - loss: 0.8328 - accuracy: 0.8075 - val_loss: 0.7311 - val_accuracy: 0.8490
# Epoch 3/50
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5398 - accuracy: 0.8927 - val_loss: 0.5868 - val_accuracy: 0.8523
# Epoch 4/50
# 37/37 [==============================] - 3s 69ms/step - loss: 0.4395 - accuracy: 0.9105 - val_loss: 0.5612 - val_accuracy: 0.8507
# Epoch 5/50
# 37/37 [==============================] - 2s 50ms/step - loss: 0.3687 - accuracy: 0.9245 - val_loss: 0.5587 - val_accuracy: 0.8557
# Epoch 6/50
# 37/37 [==============================] - 3s 69ms/step - loss: 0.3317 - accuracy: 0.9296 - val_loss: 0.4369 - val_accuracy: 0.8893
# Epoch 7/50
# 37/37 [==============================] - 3s 72ms/step - loss: 0.2769 - accuracy: 0.9440 - val_loss: 0.4026 - val_accuracy: 0.8993
# Epoch 8/50
# 37/37 [==============================] - 3s 79ms/step - loss: 0.2440 - accuracy: 0.9521 - val_loss: 0.4086 - val_accuracy: 0.8943
# Epoch 9/50
# 37/37 [==============================] - 3s 72ms/step - loss: 0.2185 - accuracy: 0.9589 - val_loss: 0.4542 - val_accuracy: 0.8826
# Epoch 10/50
# 37/37 [==============================] - 3s 70ms/step - loss: 0.1969 - accuracy: 0.9606 - val_loss: 0.3341 - val_accuracy: 0.9077
# Epoch 11/50
# 37/37 [==============================] - 2s 45ms/step - loss: 0.1765 - accuracy: 0.9652 - val_loss: 0.3319 - val_accuracy: 0.9144
# Epoch 12/50
# 37/37 [==============================] - 3s 72ms/step - loss: 0.1607 - accuracy: 0.9695 - val_loss: 0.3548 - val_accuracy: 0.9027
# Epoch 13/50
# 37/37 [==============================] - 3s 67ms/step - loss: 0.1714 - accuracy: 0.9606 - val_loss: 0.3492 - val_accuracy: 0.8993
# Epoch 14/50
# 37/37 [==============================] - 3s 76ms/step - loss: 0.1557 - accuracy: 0.9661 - val_loss: 0.3427 - val_accuracy: 0.9044
# Epoch 15/50
# 37/37 [==============================] - 3s 72ms/step - loss: 0.1278 - accuracy: 0.9758 - val_loss: 0.2887 - val_accuracy: 0.9195
# Epoch 16/50
# 37/37 [==============================] - 3s 71ms/step - loss: 0.1028 - accuracy: 0.9788 - val_loss: 0.3460 - val_accuracy: 0.8893
# Epoch 17/50
# 37/37 [==============================] - 2s 48ms/step - loss: 0.0997 - accuracy: 0.9843 - val_loss: 0.2894 - val_accuracy: 0.9279
# Epoch 18/50
# 37/37 [==============================] - 2s 52ms/step - loss: 0.0883 - accuracy: 0.9856 - val_loss: 0.3335 - val_accuracy: 0.9044
# Epoch 19/50
# 37/37 [==============================] - 3s 79ms/step - loss: 0.0902 - accuracy: 0.9826 - val_loss: 0.2788 - val_accuracy: 0.9195
# Epoch 20/50
# 37/37 [==============================] - 2s 65ms/step - loss: 0.0972 - accuracy: 0.9792 - val_loss: 0.2578 - val_accuracy: 0.9346
# Epoch 21/50
# 37/37 [==============================] - 3s 80ms/step - loss: 0.0725 - accuracy: 0.9885 - val_loss: 0.2697 - val_accuracy: 0.9228
# Epoch 22/50
# 37/37 [==============================] - 3s 69ms/step - loss: 0.0643 - accuracy: 0.9924 - val_loss: 0.2303 - val_accuracy: 0.9379
# Epoch 23/50
# 37/37 [==============================] - 2s 47ms/step - loss: 0.0618 - accuracy: 0.9898 - val_loss: 0.2624 - val_accuracy: 0.9144
# Epoch 24/50
# 37/37 [==============================] - 3s 68ms/step - loss: 0.0580 - accuracy: 0.9902 - val_loss: 0.2409 - val_accuracy: 0.9195
# Epoch 25/50
# 37/37 [==============================] - 3s 74ms/step - loss: 0.0472 - accuracy: 0.9924 - val_loss: 0.2236 - val_accuracy: 0.9312
# Epoch 26/50
# 37/37 [==============================] - 3s 82ms/step - loss: 0.0471 - accuracy: 0.9924 - val_loss: 0.2162 - val_accuracy: 0.9362
# Epoch 27/50
# 37/37 [==============================] - 2s 66ms/step - loss: 0.0381 - accuracy: 0.9962 - val_loss: 0.2510 - val_accuracy: 0.9295
# Epoch 28/50
# 37/37 [==============================] - 3s 78ms/step - loss: 0.0387 - accuracy: 0.9949 - val_loss: 0.2216 - val_accuracy: 0.9362
# Epoch 29/50
# 37/37 [==============================] - 2s 47ms/step - loss: 0.0416 - accuracy: 0.9932 - val_loss: 0.2213 - val_accuracy: 0.9396
# Epoch 30/50
# 37/37 [==============================] - 2s 66ms/step - loss: 0.0341 - accuracy: 0.9953 - val_loss: 0.2631 - val_accuracy: 0.9379
# Epoch 31/50
# 37/37 [==============================] - 3s 72ms/step - loss: 0.0443 - accuracy: 0.9932 - val_loss: 0.2560 - val_accuracy: 0.9262
# Epoch 32/50
# 37/37 [==============================] - 2s 61ms/step - loss: 0.0343 - accuracy: 0.9945 - val_loss: 0.2305 - val_accuracy: 0.9379
# Epoch 33/50
# 37/37 [==============================] - 3s 89ms/step - loss: 0.0267 - accuracy: 0.9975 - val_loss: 0.2199 - val_accuracy: 0.9329
# Epoch 34/50
# 37/37 [==============================] - 3s 77ms/step - loss: 0.0218 - accuracy: 0.9992 - val_loss: 0.2206 - val_accuracy: 0.9446
# Epoch 35/50
# 37/37 [==============================] - 2s 50ms/step - loss: 0.0210 - accuracy: 0.9996 - val_loss: 0.2125 - val_accuracy: 0.9413
# Epoch 36/50
# 37/37 [==============================] - 2s 63ms/step - loss: 0.0186 - accuracy: 1.0000 - val_loss: 0.2121 - val_accuracy: 0.9379
# Epoch 37/50
# 37/37 [==============================] - 3s 81ms/step - loss: 0.0188 - accuracy: 0.9996 - val_loss: 0.2043 - val_accuracy: 0.9362
# Epoch 38/50
# 37/37 [==============================] - 2s 61ms/step - loss: 0.0186 - accuracy: 0.9996 - val_loss: 0.2132 - val_accuracy: 0.9362
# Epoch 39/50
# 37/37 [==============================] - 3s 79ms/step - loss: 0.0175 - accuracy: 0.9983 - val_loss: 0.2137 - val_accuracy: 0.9430
# Epoch 40/50
# 37/37 [==============================] - 3s 73ms/step - loss: 0.0181 - accuracy: 0.9979 - val_loss: 0.2216 - val_accuracy: 0.9413
# Epoch 41/50
# 37/37 [==============================] - 2s 62ms/step - loss: 0.0146 - accuracy: 0.9996 - val_loss: 0.1995 - val_accuracy: 0.9463
# Epoch 42/50
# 37/37 [==============================] - 2s 46ms/step - loss: 0.0124 - accuracy: 1.0000 - val_loss: 0.2092 - val_accuracy: 0.9396
# Epoch 43/50
# 37/37 [==============================] - 3s 69ms/step - loss: 0.0126 - accuracy: 1.0000 - val_loss: 0.2006 - val_accuracy: 0.9463
# Epoch 44/50
# 37/37 [==============================] - 3s 69ms/step - loss: 0.0127 - accuracy: 0.9996 - val_loss: 0.1997 - val_accuracy: 0.9480
# Epoch 45/50
# 37/37 [==============================] - 2s 64ms/step - loss: 0.0114 - accuracy: 1.0000 - val_loss: 0.1988 - val_accuracy: 0.9446
# Epoch 46/50
# 37/37 [==============================] - 2s 56ms/step - loss: 0.0114 - accuracy: 1.0000 - val_loss: 0.2048 - val_accuracy: 0.9446
# Epoch 47/50
# 37/37 [==============================] - 2s 62ms/step - loss: 0.0112 - accuracy: 0.9996 - val_loss: 0.2016 - val_accuracy: 0.9463
# Epoch 48/50
# 37/37 [==============================] - 2s 65ms/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.2045 - val_accuracy: 0.9396
# Epoch 49/50
# 37/37 [==============================] - 2s 56ms/step - loss: 0.0094 - accuracy: 0.9996 - val_loss: 0.2195 - val_accuracy: 0.9430
# Epoch 50/50
# 37/37 [==============================] - 3s 73ms/step - loss: 0.0106 - accuracy: 1.0000 - val_loss: 0.2043 - val_accuracy: 0.9413

# %%
import matplotlib.pyplot as plt

def plot_training_history(history):
    """
    Plot training and validation metrics based on the History object from a Keras model.

    Parameters:
    - history: History object returned from the fit method.
    """
    epochs_range = range(1, len(history.history['accuracy']) + 1)  # Assuming there's at least the 'accuracy' metric
    metrics = [key for key in history.history.keys() if not key.startswith("val_")]  # Retrieve all non-validation metrics
    _, axes = plt.subplots(1, len(metrics), figsize=(20, 4))  # Dynamically adjust the number of subplots based on the number of metrics

    for idx, metric in enumerate(metrics):
        # Plot the training and validation curve for each metric in each subplot
        axes[idx].plot(epochs_range, history.history[metric], label=f'Training {metric.capitalize()}')
        axes[idx].plot(epochs_range, history.history[f"val_{metric}"], label=f'Validation {metric.capitalize()}')
        axes[idx].legend()
        axes[idx].set_title(f'Training and Validation {metric.capitalize()}')
        axes[idx].set_xlabel('Epoch')
        axes[idx].set_ylabel(metric.capitalize())
    
    plt.tight_layout()
    plt.show()

# Assuming history_baseline_categorical is the training history object of your MLP model
# Call the function to plot
plot_training_history(history_baseline_categorical)

# %%
train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255,
    rotation_range=30,  # Rotation range (degrees), adjustable range, e.g., 20-40
    width_shift_range=0.1,  # Horizontal shift range
    height_shift_range=0.1,  # Vertical shift range
    shear_range=0.1,  # Shearing range
    zoom_range=0.1,  # Zoom range
    horizontal_flip=True,  # Horizontal flip
)
val_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)
test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_dataframe(
    dataframe=train_df,
    x_col='ImagePath',
    y_col='Label',
    color_mode='grayscale',
    target_size=(28, 28),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=True
)

val_generator = val_datagen.flow_from_dataframe(
    dataframe=validation_df,
    x_col='ImagePath',
    y_col='Label',
    color_mode='grayscale',
    target_size=(28, 28),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)

test_generator = test_datagen.flow_from_dataframe(
    dataframe=test_df,
    x_col='ImagePath',
    y_col='Label',
    color_mode='grayscale',
    target_size=(28, 28),
    batch_size=batch_size,
    class_mode='categorical',  
    shuffle=False
)
# Out:
# Found 2358 validated image filenames belonging to 16 classes.
# Found 596 validated image filenames belonging to 16 classes.
# Found 745 validated image filenames belonging to 16 classes.

# %%
import numpy as np
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

def get_data_from_generator(generator):
    batches = []
    labels = []
    # Iterate over the generator to collect data and labels
    for batch, label in generator:
        batches.append(batch)
        labels.append(label)
        if len(batches) >= len(generator):
            break  # Ensure there is no infinite iteration
    return np.vstack(batches), np.vstack(labels)

X_train, y_train = get_data_from_generator(train_generator)
X_val, y_val = get_data_from_generator(val_generator)
X_test, y_test = get_data_from_generator(test_generator)

# Reshape the data to fit the input requirements of StandardScaler
X_train = X_train.reshape(X_train.shape[0], -1)
X_val = X_val.reshape(X_val.shape[0], -1)
X_test = X_test.reshape(X_test.shape[0], -1)

# Assuming y_train and y_val are one-hot encoded, with shape (number of samples, number of classes)
y_train = np.argmax(y_train, axis=1)
y_val = np.argmax(y_val, axis=1)

# Initialize and apply standardization
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled = scaler.transform(X_val)

# Initialize SVM model
svm_model = SVC(kernel='rbf', C=1.0, gamma='auto', max_iter=1000)

# Train the SVM model
svm_model.fit(X_train_scaled, y_train)

# Evaluate the SVM model on the validation set
y_pred_val = svm_model.predict(X_val_scaled)
print("Validation Accuracy:", accuracy_score(y_val, y_pred_val))
# Out:
# Validation Accuracy: 0.6946308724832215

# %%
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

report = classification_report(y_val, y_pred_val, target_names=label_names, zero_division=1)
print(report)

cm = confusion_matrix(y_val, y_pred_val)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt="d", cmap='Blues', xticklabels=label_names, yticklabels=label_names)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()
# Out:
#                   precision    recall  f1-score   support
#
#          bicycle       0.70      0.67      0.69        46
#         continue       0.72      0.91      0.81        32
#         crossing       1.00      0.00      0.00        16
#          giveway       0.77      0.81      0.79        37
#          laneend       1.00      0.42      0.59        19
#   limitedtraffic       0.91      0.50      0.65        20
#          noentry       0.77      0.97      0.86        60
#        noparking       0.52      0.77      0.62        39
#          parking       0.76      0.86      0.81        44
#       rightofway       0.76      0.58      0.66        45
#       roundabout       1.00      0.00      0.00        16
#            speed       0.50      0.76      0.60        51
#             stop       1.00      0.00      0.00         7
# trafficdirective       1.00      0.28      0.44        32
#  traveldirection       1.00      0.05      0.10        20
#          warning       0.70      0.94      0.80       112
#
#         accuracy                           0.69       596
#        macro avg       0.82      0.53      0.53       596
#     weighted avg       0.76      0.69      0.65       596

# %%
num_classes = 16
input_shape = (28, 28)
baseline_categorical = tf.keras.models.Sequential([
    tf.keras.Input(shape=input_shape),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(num_classes, activation='softmax')
])

# %%
baseline_categorical.compile(loss='binary_crossentropy',
                        optimizer=tf.keras.optimizers.Adam(),
                        metrics=['accuracy'])

# %%
epochs = 50
history_baseline_categorical = baseline_categorical.fit(
    train_generator,
    validation_data=val_generator,
    epochs=epochs
)
# Out:
# Epoch 1/50
# 37/37 [==============================] - 7s 138ms/step - loss: 0.2611 - accuracy: 0.2260 - val_loss: 0.2106 - val_accuracy: 0.3054
# Epoch 2/50
# 37/37 [==============================] - 4s 108ms/step - loss: 0.2114 - accuracy: 0.3257 - val_loss: 0.1899 - val_accuracy: 0.4480
# Epoch 3/50
# 37/37 [==============================] - 5s 124ms/step - loss: 0.1996 - accuracy: 0.3872 - val_loss: 0.1681 - val_accuracy: 0.5201
# Epoch 4/50
# 37/37 [==============================] - 5s 131ms/step - loss: 0.1900 - accuracy: 0.4016 - val_loss: 0.1626 - val_accuracy: 0.5503
# Epoch 5/50
# 37/37 [==============================] - 5s 121ms/step - loss: 0.1817 - accuracy: 0.4372 - val_loss: 0.1539 - val_accuracy: 0.5856
# Epoch 6/50
# 37/37 [==============================] - 4s 111ms/step - loss: 0.1767 - accuracy: 0.4444 - val_loss: 0.1515 - val_accuracy: 0.5956
# Epoch 7/50
# 37/37 [==============================] - 4s 116ms/step - loss: 0.1699 - accuracy: 0.4813 - val_loss: 0.1446 - val_accuracy: 0.5755
# Epoch 8/50
# 37/37 [==============================] - 4s 115ms/step - loss: 0.1686 - accuracy: 0.4830 - val_loss: 0.1376 - val_accuracy: 0.6158
# Epoch 9/50
# 37/37 [==============================] - 4s 102ms/step - loss: 0.1633 - accuracy: 0.5034 - val_loss: 0.1319 - val_accuracy: 0.6762
# Epoch 10/50
# 37/37 [==============================] - 4s 111ms/step - loss: 0.1582 - accuracy: 0.5221 - val_loss: 0.1275 - val_accuracy: 0.6409
# Epoch 11/50
# 37/37 [==============================] - 4s 114ms/step - loss: 0.1554 - accuracy: 0.5339 - val_loss: 0.1277 - val_accuracy: 0.6862
# Epoch 12/50
# 37/37 [==============================] - 4s 120ms/step - loss: 0.1509 - accuracy: 0.5445 - val_loss: 0.1208 - val_accuracy: 0.6980
# Epoch 13/50
# 37/37 [==============================] - 4s 117ms/step - loss: 0.1490 - accuracy: 0.5488 - val_loss: 0.1247 - val_accuracy: 0.6477
# Epoch 14/50
# 37/37 [==============================] - 4s 103ms/step - loss: 0.1504 - accuracy: 0.5394 - val_loss: 0.1140 - val_accuracy: 0.6946
# Epoch 15/50
# 37/37 [==============================] - 3s 90ms/step - loss: 0.1464 - accuracy: 0.5606 - val_loss: 0.1107 - val_accuracy: 0.7030
# Epoch 16/50
# 37/37 [==============================] - 5s 127ms/step - loss: 0.1421 - accuracy: 0.5696 - val_loss: 0.1127 - val_accuracy: 0.6862
# Epoch 17/50
# 37/37 [==============================] - 4s 102ms/step - loss: 0.1414 - accuracy: 0.5674 - val_loss: 0.1098 - val_accuracy: 0.6997
# Epoch 18/50
# 37/37 [==============================] - 4s 116ms/step - loss: 0.1372 - accuracy: 0.5738 - val_loss: 0.1055 - val_accuracy: 0.7349
# Epoch 19/50
# 37/37 [==============================] - 4s 112ms/step - loss: 0.1361 - accuracy: 0.5827 - val_loss: 0.1059 - val_accuracy: 0.7064
# Epoch 20/50
# 37/37 [==============================] - 4s 104ms/step - loss: 0.1336 - accuracy: 0.5997 - val_loss: 0.1027 - val_accuracy: 0.7198
# Epoch 21/50
# 37/37 [==============================] - 4s 103ms/step - loss: 0.1317 - accuracy: 0.5980 - val_loss: 0.0996 - val_accuracy: 0.7366
# Epoch 22/50
# 37/37 [==============================] - 4s 112ms/step - loss: 0.1290 - accuracy: 0.6026 - val_loss: 0.1012 - val_accuracy: 0.7248
# Epoch 23/50
# 37/37 [==============================] - 4s 115ms/step - loss: 0.1314 - accuracy: 0.6014 - val_loss: 0.0976 - val_accuracy: 0.7315
# Epoch 24/50
# 37/37 [==============================] - 4s 117ms/step - loss: 0.1265 - accuracy: 0.6217 - val_loss: 0.0975 - val_accuracy: 0.7416
# Epoch 25/50
# 37/37 [==============================] - 4s 106ms/step - loss: 0.1289 - accuracy: 0.6039 - val_loss: 0.0963 - val_accuracy: 0.7584
# Epoch 26/50
# 37/37 [==============================] - 4s 115ms/step - loss: 0.1260 - accuracy: 0.6213 - val_loss: 0.0962 - val_accuracy: 0.7282
# Epoch 27/50
# 37/37 [==============================] - 4s 122ms/step - loss: 0.1223 - accuracy: 0.6238 - val_loss: 0.0951 - val_accuracy: 0.7466
# Epoch 28/50
# 37/37 [==============================] - 4s 118ms/step - loss: 0.1240 - accuracy: 0.6243 - val_loss: 0.0894 - val_accuracy: 0.7685
# Epoch 29/50
# 37/37 [==============================] - 4s 95ms/step - loss: 0.1233 - accuracy: 0.6255 - val_loss: 0.0870 - val_accuracy: 0.7701
# Epoch 30/50
# 37/37 [==============================] - 4s 103ms/step - loss: 0.1202 - accuracy: 0.6370 - val_loss: 0.0882 - val_accuracy: 0.7869
# Epoch 31/50
# 37/37 [==============================] - 4s 112ms/step - loss: 0.1182 - accuracy: 0.6442 - val_loss: 0.0904 - val_accuracy: 0.7735
# Epoch 32/50
# 37/37 [==============================] - 4s 110ms/step - loss: 0.1177 - accuracy: 0.6459 - val_loss: 0.0871 - val_accuracy: 0.7634
# Epoch 33/50
# 37/37 [==============================] - 4s 100ms/step - loss: 0.1176 - accuracy: 0.6489 - val_loss: 0.0833 - val_accuracy: 0.7886
# Epoch 34/50
# 37/37 [==============================] - 4s 110ms/step - loss: 0.1164 - accuracy: 0.6578 - val_loss: 0.0871 - val_accuracy: 0.7668
# Epoch 35/50
# 37/37 [==============================] - 4s 122ms/step - loss: 0.1164 - accuracy: 0.6480 - val_loss: 0.0857 - val_accuracy: 0.7802
# Epoch 36/50
# 37/37 [==============================] - 5s 128ms/step - loss: 0.1140 - accuracy: 0.6561 - val_loss: 0.0869 - val_accuracy: 0.7500
# Epoch 37/50
# 37/37 [==============================] - 4s 99ms/step - loss: 0.1142 - accuracy: 0.6472 - val_loss: 0.0804 - val_accuracy: 0.8020
# Epoch 38/50
# 37/37 [==============================] - 4s 115ms/step - loss: 0.1092 - accuracy: 0.6739 - val_loss: 0.0806 - val_accuracy: 0.7836
# Epoch 39/50
# 37/37 [==============================] - 4s 112ms/step - loss: 0.1100 - accuracy: 0.6633 - val_loss: 0.0796 - val_accuracy: 0.8054
# Epoch 40/50
# 37/37 [==============================] - 4s 113ms/step - loss: 0.1101 - accuracy: 0.6701 - val_loss: 0.0782 - val_accuracy: 0.8070
# Epoch 41/50
# 37/37 [==============================] - 4s 102ms/step - loss: 0.1086 - accuracy: 0.6853 - val_loss: 0.0805 - val_accuracy: 0.7886
# Epoch 42/50
# 37/37 [==============================] - 5s 121ms/step - loss: 0.1090 - accuracy: 0.6794 - val_loss: 0.0803 - val_accuracy: 0.7919
# Epoch 43/50
# 37/37 [==============================] - 5s 126ms/step - loss: 0.1073 - accuracy: 0.6870 - val_loss: 0.0771 - val_accuracy: 0.7886
# Epoch 44/50
# 37/37 [==============================] - 4s 105ms/step - loss: 0.1091 - accuracy: 0.6751 - val_loss: 0.0754 - val_accuracy: 0.8205
# Epoch 45/50
# 37/37 [==============================] - 4s 115ms/step - loss: 0.1053 - accuracy: 0.6883 - val_loss: 0.0737 - val_accuracy: 0.8255
# Epoch 46/50
# 37/37 [==============================] - 4s 98ms/step - loss: 0.1064 - accuracy: 0.6866 - val_loss: 0.0759 - val_accuracy: 0.8121
# Epoch 47/50
# 37/37 [==============================] - 4s 115ms/step - loss: 0.1050 - accuracy: 0.6891 - val_loss: 0.0742 - val_accuracy: 0.8272
# Epoch 48/50
# 37/37 [==============================] - 3s 89ms/step - loss: 0.1035 - accuracy: 0.6985 - val_loss: 0.0758 - val_accuracy: 0.7953
# Epoch 49/50
# 37/37 [==============================] - 4s 121ms/step - loss: 0.1041 - accuracy: 0.7040 - val_loss: 0.0719 - val_accuracy: 0.8305
# Epoch 50/50
# 37/37 [==============================] - 4s 119ms/step - loss: 0.1014 - accuracy: 0.6968 - val_loss: 0.0713 - val_accuracy: 0.8255

# %%
import matplotlib.pyplot as plt

def plot_training_history(history):
    epochs_range = range(1, len(history.history['accuracy']) + 1) 
    metrics = [key for key in history.history.keys() if not key.startswith("val_")]  
    _, axes = plt.subplots(1, len(metrics), figsize=(20, 4))  

    for idx, metric in enumerate(metrics):
        axes[idx].plot(epochs_range, history.history[metric], label=f'Training {metric.capitalize()}')
        axes[idx].plot(epochs_range, history.history[f"val_{metric}"], label=f'Validation {metric.capitalize()}')
        axes[idx].legend()
        axes[idx].set_title(f'Training and Validation {metric.capitalize()}')
        axes[idx].set_xlabel('Epoch')
        axes[idx].set_ylabel(metric.capitalize())
    
    plt.tight_layout()
    plt.show()

plot_training_history(history_baseline_categorical)

# %%
y_pred_val_prob = baseline_categorical.predict(val_generator)
y_pred_val = np.argmax(y_pred_val_prob, axis=1)

from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

report = classification_report(val_generator.classes, y_pred_val, target_names=label_names)
print(report)

cm = confusion_matrix(val_generator.classes, y_pred_val)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt="d", cmap='Blues', xticklabels=label_names, yticklabels=label_names)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()
# Out:
# 10/10 [==============================] - 1s 41ms/step
#                   precision    recall  f1-score   support
#
#          bicycle       0.87      0.89      0.88        46
#         continue       0.78      0.97      0.86        32
#         crossing       1.00      0.50      0.67        16
#          giveway       0.92      0.89      0.90        37
#          laneend       1.00      0.84      0.91        19
#   limitedtraffic       0.62      0.75      0.68        20
#          noentry       0.84      0.98      0.91        60
#        noparking       0.86      0.82      0.84        39
#          parking       0.81      0.98      0.89        44
#       rightofway       0.87      0.76      0.81        45
#       roundabout       0.83      0.62      0.71        16
#            speed       0.69      0.78      0.73        51
#             stop       0.80      0.57      0.67         7
# trafficdirective       0.87      0.41      0.55        32
#  traveldirection       1.00      0.15      0.26        20
#          warning       0.83      0.98      0.90       112
#
#         accuracy                           0.83       596
#        macro avg       0.85      0.74      0.76       596
#     weighted avg       0.84      0.83      0.81       596

# %%
from tensorflow.keras import models, layers

num_classes = 16  # Adjust the number of classes according to your task

cnn_model = models.Sequential([
    layers.Input(shape=(28, 28, 1)),  # Input for grayscale images, 1 channel
    layers.Conv2D(32, (3, 3), padding='same'),  # First convolutional layer, 32 filters
    layers.BatchNormalization(),  # Adding batch normalization
    layers.Activation('relu'),  # Activation layer
    layers.MaxPooling2D((2, 2)),  # Max pooling
    layers.Conv2D(64, (3, 3), padding='same'),  # Second convolutional layer, 64 filters
    layers.BatchNormalization(),  # Adding batch normalization
    layers.Activation('relu'),  # Activation layer
    layers.MaxPooling2D((2, 2)),  # Max pooling
    layers.Conv2D(128, (3, 3), padding='same'),  # Third convolutional layer, 128 filters
    layers.BatchNormalization(),  # Adding batch normalization
    layers.Activation('relu'),  # Activation layer
    layers.MaxPooling2D((2, 2)),  # Max pooling
    layers.Flatten(),  # Flatten the convolutional result
    layers.Dense(512),  # Fully connected layer
    layers.BatchNormalization(),  # Adding batch normalization
    layers.Activation('relu'),  # Activation layer
    layers.Dense(num_classes, activation='softmax')  # Output layer, using softmax activation
])

from tensorflow.keras.callbacks import Callback
import numpy as np

class PerClassAccuracy(Callback):
    def __init__(self, validation_generator, num_classes):
        super().__init__()
        self.validation_generator = validation_generator
        self.num_classes = num_classes
        self.history = {'val_accuracy_per_class': []}

    def on_epoch_end(self, epoch, logs=None):
        val_preds = self.model.predict(self.validation_generator)
        val_classes = np.argmax(val_preds, axis=1)
        true_classes = self.validation_generator.classes
        correct_preds = np.zeros(self.num_classes)
        total_preds = np.zeros(self.num_classes)

        for i in range(self.num_classes):
            for true, pred in zip(true_classes, val_classes):
                if true == i:
                    total_preds[i] += 1
                    if true == pred:
                        correct_preds[i] += 1

        accuracy_per_class = correct_preds / total_preds
        self.history['val_accuracy_per_class'].append(accuracy_per_class)

# Usage
num_classes = 16
validation_data = val_generator  # Assume val_generator is already defined
per_class_accuracy_callback = PerClassAccuracy(validation_data, num_classes)

cnn_model.compile(
    loss='categorical_crossentropy',  # Using categorical crossentropy loss
    optimizer=tf.keras.optimizers.Adam(),  # Adam optimizer
    metrics=['accuracy']  # Using accuracy as metric
)

# %%
epochs = 50
history_cnn = cnn_model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=epochs,
    callbacks=[per_class_accuracy_callback],
    verbose=1
)
# Out:
# Epoch 1/50
# 10/10 [==============================] - 1s 52ms/stepss: 1.3415 -
# 37/37 [==============================] - 11s 204ms/step - loss: 1.3415 - accuracy: 0.6073 - val_loss: 2.8794 - val_accuracy: 0.0654
# Epoch 2/50
# 10/10 [==============================] - 1s 48ms/stepss: 0.5362 - ac
# 37/37 [==============================] - 7s 179ms/step - loss: 0.5362 - accuracy: 0.8410 - val_loss: 3.3095 - val_accuracy: 0.0654
# Epoch 3/50
# 10/10 [==============================] - 1s 63ms/stepss: 0.3397
# 37/37 [==============================] - 6s 161ms/step - loss: 0.3397 - accuracy: 0.9020 - val_loss: 3.7173 - val_accuracy: 0.0839
# Epoch 4/50
# 10/10 [==============================] - 1s 70ms/stepss: 0.2481
# 37/37 [==============================] - 7s 184ms/step - loss: 0.2481 - accuracy: 0.9334 - val_loss: 4.3166 - val_accuracy: 0.1342
# Epoch 5/50
# 10/10 [==============================] - 1s 43ms/stepss: 0.2216 - ac
# 37/37 [==============================] - 6s 157ms/step - loss: 0.2216 - accuracy: 0.9347 - val_loss: 3.8722 - val_accuracy: 0.1191
# Epoch 6/50
# 10/10 [==============================] - 1s 54ms/stepss: 0.1747
# 37/37 [==============================] - 7s 180ms/step - loss: 0.1747 - accuracy: 0.9444 - val_loss: 3.9949 - val_accuracy: 0.1594
# Epoch 7/50
# 10/10 [==============================] - 1s 51ms/stepss: 0.1592 -
# 37/37 [==============================] - 7s 180ms/step - loss: 0.1592 - accuracy: 0.9529 - val_loss: 3.2488 - val_accuracy: 0.2232
# Epoch 8/50
# 10/10 [==============================] - 1s 50ms/stepss: 0.1209 -
# 37/37 [==============================] - 6s 162ms/step - loss: 0.1209 - accuracy: 0.9648 - val_loss: 1.9892 - val_accuracy: 0.4866
# Epoch 9/50
# 10/10 [==============================] - 1s 56ms/stepss: 0.1313
# 37/37 [==============================] - 7s 179ms/step - loss: 0.1313 - accuracy: 0.9610 - val_loss: 2.0866 - val_accuracy: 0.4983
# Epoch 10/50
# 10/10 [==============================] - 1s 50ms/stepss: 0.1104 - ac
# 37/37 [==============================] - 6s 161ms/step - loss: 0.1104 - accuracy: 0.9661 - val_loss: 1.0952 - val_accuracy: 0.6829
# Epoch 11/50
# 10/10 [==============================] - 1s 57ms/stepss: 0.1271 -
# 37/37 [==============================] - 7s 181ms/step - loss: 0.1271 - accuracy: 0.9572 - val_loss: 0.8983 - val_accuracy: 0.7416
# Epoch 12/50
# 10/10 [==============================] - 0s 43ms/stepss: 0.1021 - accu
# 37/37 [==============================] - 7s 182ms/step - loss: 0.1021 - accuracy: 0.9707 - val_loss: 0.3656 - val_accuracy: 0.8775
# Epoch 13/50
# 10/10 [==============================] - 1s 57ms/stepss: 0.0926 -
# 37/37 [==============================] - 6s 170ms/step - loss: 0.0926 - accuracy: 0.9724 - val_loss: 0.3684 - val_accuracy: 0.8742
# Epoch 14/50
# 10/10 [==============================] - 1s 57ms/stepss: 0.0878
# 37/37 [==============================] - 7s 181ms/step - loss: 0.0878 - accuracy: 0.9746 - val_loss: 0.2246 - val_accuracy: 0.9346
# Epoch 15/50
# 10/10 [==============================] - 1s 58ms/stepss: 0.0749
# 37/37 [==============================] - 6s 162ms/step - loss: 0.0749 - accuracy: 0.9779 - val_loss: 0.0888 - val_accuracy: 0.9732
# Epoch 16/50
# 10/10 [==============================] - 1s 59ms/stepss: 0.0730
# 37/37 [==============================] - 7s 184ms/step - loss: 0.0730 - accuracy: 0.9779 - val_loss: 0.0891 - val_accuracy: 0.9765
# Epoch 17/50
# 10/10 [==============================] - 0s 35ms/stepss: 0.0603 - accura
# 37/37 [==============================] - 6s 166ms/step - loss: 0.0603 - accuracy: 0.9839 - val_loss: 0.0782 - val_accuracy: 0.9782
# Epoch 18/50
# 10/10 [==============================] - 1s 59ms/stepss: 0.0667
# 37/37 [==============================] - 6s 168ms/step - loss: 0.0667 - accuracy: 0.9779 - val_loss: 0.0568 - val_accuracy: 0.9832
# Epoch 19/50
# 10/10 [==============================] - 1s 55ms/stepss: 0.0710 -
# 37/37 [==============================] - 7s 184ms/step - loss: 0.0710 - accuracy: 0.9775 - val_loss: 0.0704 - val_accuracy: 0.9832
# Epoch 20/50
# 10/10 [==============================] - 1s 58ms/stepss: 0.0472
# 37/37 [==============================] - 6s 163ms/step - loss: 0.0472 - accuracy: 0.9869 - val_loss: 0.0440 - val_accuracy: 0.9849
# Epoch 21/50
# 10/10 [==============================] - 1s 53ms/stepss: 0.0475
# 37/37 [==============================] - 7s 176ms/step - loss: 0.0475 - accuracy: 0.9847 - val_loss: 0.0389 - val_accuracy: 0.9866
# Epoch 22/50
# 10/10 [==============================] - 0s 36ms/stepss: 0.0599 - accu
# 37/37 [==============================] - 6s 170ms/step - loss: 0.0599 - accuracy: 0.9818 - val_loss: 0.0485 - val_accuracy: 0.9849
# Epoch 23/50
# 10/10 [==============================] - 1s 66ms/stepss: 0.0521 -
# 37/37 [==============================] - 7s 178ms/step - loss: 0.0521 - accuracy: 0.9826 - val_loss: 0.0403 - val_accuracy: 0.9916
# Epoch 24/50
# 10/10 [==============================] - 1s 55ms/stepss: 0.0609
# 37/37 [==============================] - 7s 187ms/step - loss: 0.0609 - accuracy: 0.9826 - val_loss: 0.1051 - val_accuracy: 0.9631
# Epoch 25/50
# 10/10 [==============================] - 1s 55ms/stepss: 0.0518
# 37/37 [==============================] - 6s 161ms/step - loss: 0.0518 - accuracy: 0.9839 - val_loss: 0.0287 - val_accuracy: 0.9916
# Epoch 26/50
# 10/10 [==============================] - 1s 52ms/stepss: 0.0439 -
# 37/37 [==============================] - 7s 185ms/step - loss: 0.0439 - accuracy: 0.9856 - val_loss: 0.0511 - val_accuracy: 0.9799
# Epoch 27/50
# 10/10 [==============================] - 0s 43ms/stepss: 0.0432 - ac
# 37/37 [==============================] - 6s 167ms/step - loss: 0.0432 - accuracy: 0.9873 - val_loss: 0.0300 - val_accuracy: 0.9899
# Epoch 28/50
# 10/10 [==============================] - 1s 54ms/stepss: 0.0361 -
# 37/37 [==============================] - 7s 178ms/step - loss: 0.0361 - accuracy: 0.9898 - val_loss: 0.0248 - val_accuracy: 0.9899
# Epoch 29/50
# 10/10 [==============================] - 1s 54ms/stepss: 0.0405 -
# 37/37 [==============================] - 7s 182ms/step - loss: 0.0405 - accuracy: 0.9890 - val_loss: 0.0311 - val_accuracy: 0.9916
# Epoch 30/50
# 10/10 [==============================] - 1s 53ms/stepss: 0.0350 -
# 37/37 [==============================] - 6s 168ms/step - loss: 0.0350 - accuracy: 0.9898 - val_loss: 0.0255 - val_accuracy: 0.9933
# Epoch 31/50
# 10/10 [==============================] - 1s 53ms/stepss: 0.0379 -
# 37/37 [==============================] - 7s 183ms/step - loss: 0.0379 - accuracy: 0.9890 - val_loss: 0.0395 - val_accuracy: 0.9832
# Epoch 32/50
# 10/10 [==============================] - 1s 40ms/stepss: 0.0339 - accu
# 37/37 [==============================] - 6s 164ms/step - loss: 0.0339 - accuracy: 0.9881 - val_loss: 0.0186 - val_accuracy: 0.9950
# Epoch 33/50
# 10/10 [==============================] - 1s 58ms/stepss: 0.0340 -
# 37/37 [==============================] - 7s 182ms/step - loss: 0.0340 - accuracy: 0.9907 - val_loss: 0.0166 - val_accuracy: 0.9950
# Epoch 34/50
# 10/10 [==============================] - 1s 46ms/stepss: 0.0521 - accu
# 37/37 [==============================] - 7s 183ms/step - loss: 0.0521 - accuracy: 0.9852 - val_loss: 0.0419 - val_accuracy: 0.9883
# Epoch 35/50
# 10/10 [==============================] - 1s 50ms/stepss: 0.0488 -
# 37/37 [==============================] - 6s 162ms/step - loss: 0.0488 - accuracy: 0.9847 - val_loss: 0.0576 - val_accuracy: 0.9849
# Epoch 36/50
# 10/10 [==============================] - 1s 57ms/stepss: 0.0413
# 37/37 [==============================] - 7s 183ms/step - loss: 0.0413 - accuracy: 0.9873 - val_loss: 0.0691 - val_accuracy: 0.9732
# Epoch 37/50
# 10/10 [==============================] - 1s 54ms/stepss: 0.0384
# 37/37 [==============================] - 6s 160ms/step - loss: 0.0384 - accuracy: 0.9869 - val_loss: 0.0457 - val_accuracy: 0.9799
# Epoch 38/50
# 10/10 [==============================] - 1s 57ms/stepss: 0.0307
# 37/37 [==============================] - 7s 186ms/step - loss: 0.0307 - accuracy: 0.9924 - val_loss: 0.0359 - val_accuracy: 0.9899
# Epoch 39/50
# 10/10 [==============================] - 0s 41ms/stepss: 0.0412 - accu
# 37/37 [==============================] - 7s 178ms/step - loss: 0.0412 - accuracy: 0.9873 - val_loss: 0.0179 - val_accuracy: 0.9950
# Epoch 40/50
# 10/10 [==============================] - 1s 55ms/stepss: 0.0363 -
# 37/37 [==============================] - 6s 175ms/step - loss: 0.0363 - accuracy: 0.9873 - val_loss: 0.0427 - val_accuracy: 0.9866
# Epoch 41/50
# 10/10 [==============================] - 1s 57ms/stepss: 0.0358 -
# 37/37 [==============================] - 7s 187ms/step - loss: 0.0358 - accuracy: 0.9890 - val_loss: 0.0348 - val_accuracy: 0.9916
# Epoch 42/50
# 10/10 [==============================] - 1s 47ms/stepss: 0.0246 - ac
# 37/37 [==============================] - 6s 161ms/step - loss: 0.0246 - accuracy: 0.9936 - val_loss: 0.0368 - val_accuracy: 0.9883
# Epoch 43/50
# 10/10 [==============================] - 1s 59ms/stepss: 0.0398
# 37/37 [==============================] - 7s 190ms/step - loss: 0.0398 - accuracy: 0.9877 - val_loss: 0.0767 - val_accuracy: 0.9748
# Epoch 44/50
# 10/10 [==============================] - 0s 37ms/stepss: 0.0366 - accura
# 37/37 [==============================] - 6s 168ms/step - loss: 0.0366 - accuracy: 0.9873 - val_loss: 0.0388 - val_accuracy: 0.9883
# Epoch 45/50
# 10/10 [==============================] - 1s 54ms/stepss: 0.0295
# 37/37 [==============================] - 7s 185ms/step - loss: 0.0295 - accuracy: 0.9915 - val_loss: 0.0480 - val_accuracy: 0.9899
# Epoch 46/50
# 10/10 [==============================] - 1s 53ms/stepss: 0.0269
# 37/37 [==============================] - 7s 180ms/step - loss: 0.0269 - accuracy: 0.9932 - val_loss: 0.0624 - val_accuracy: 0.9849
# Epoch 47/50
# 10/10 [==============================] - 1s 54ms/stepss: 0.0276
# 37/37 [==============================] - 6s 162ms/step - loss: 0.0276 - accuracy: 0.9890 - val_loss: 0.0353 - val_accuracy: 0.9916
# Epoch 48/50
# 10/10 [==============================] - 1s 54ms/stepss: 0.0224 -
# 37/37 [==============================] - 7s 181ms/step - loss: 0.0224 - accuracy: 0.9932 - val_loss: 0.0574 - val_accuracy: 0.9799
# Epoch 49/50
# 10/10 [==============================] - 1s 48ms/stepss: 0.0303 - ac
# 37/37 [==============================] - 6s 165ms/step - loss: 0.0303 - accuracy: 0.9890 - val_loss: 0.0491 - val_accuracy: 0.9866
# Epoch 50/50
# 10/10 [==============================] - 1s 57ms/stepss: 0.0295
# 37/37 [==============================] - 7s 186ms/step - loss: 0.0295 - accuracy: 0.9890 - val_loss: 0.0159 - val_accuracy: 0.9966

# %%
import matplotlib.pyplot as plt

def plot_training_history(history):

    epochs_range = range(1, len(history.history['accuracy']) + 1)  
    metrics = [key for key in history.history.keys() if not key.startswith("val_")]  
    _, axes = plt.subplots(1, len(metrics), figsize=(20, 4))  

    for idx, metric in enumerate(metrics):
        axes[idx].plot(epochs_range, history.history[metric], label=f'Training {metric.capitalize()}')
        axes[idx].plot(epochs_range, history.history[f"val_{metric}"], label=f'Validation {metric.capitalize()}')
        axes[idx].legend()
        axes[idx].set_title(f'Training and Validation {metric.capitalize()}')
        axes[idx].set_xlabel('Epoch')
        axes[idx].set_ylabel(metric.capitalize())
    
    plt.tight_layout()
    plt.show()

plot_training_history(history_cnn)

# %%
import numpy as np

if y_pred_val_prob.ndim > 1:
    y_pred_val = np.argmax(y_pred_val_prob, axis=1)
else:
    y_pred_val = y_pred_val_prob  

y_val = val_generator.labels

from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

report = classification_report(y_val, y_pred_val, target_names=label_names)
print(report)

def plot_per_class_training_history(per_class_history, label_names):
    num_classes = len(label_names)  # 确定类别数量
    epochs_range = range(1, len(per_class_history['val_accuracy_per_class']) + 1)
    plt.figure(figsize=(20, 40))  # 根据类别数量调整图形尺寸

    for i in range(num_classes):
        plt.subplot(num_classes, 1, i+1)
        class_accuracy = [acc[i] for acc in per_class_history['val_accuracy_per_class']]
        plt.plot(epochs_range, class_accuracy, label=f'Validation Accuracy for {label_names[i]}')
        plt.legend()
        plt.title(label_names[i])  # 使用类别名称作为标题
        plt.xlabel('Epoch')
        plt.ylabel('Accuracy')

    plt.tight_layout()
    plt.show()

plot_per_class_training_history(per_class_accuracy_callback.history, label_names)
# Out:
#                   precision    recall  f1-score   support
#
#          bicycle       0.87      0.89      0.88        46
#         continue       0.78      0.97      0.86        32
#         crossing       1.00      0.50      0.67        16
#          giveway       0.92      0.89      0.90        37
#          laneend       1.00      0.84      0.91        19
#   limitedtraffic       0.62      0.75      0.68        20
#          noentry       0.84      0.98      0.91        60
#        noparking       0.86      0.82      0.84        39
#          parking       0.81      0.98      0.89        44
#       rightofway       0.87      0.76      0.81        45
#       roundabout       0.83      0.62      0.71        16
#            speed       0.69      0.78      0.73        51
#             stop       0.80      0.57      0.67         7
# trafficdirective       0.87      0.41      0.55        32
#  traveldirection       1.00      0.15      0.26        20
#          warning       0.83      0.98      0.90       112
#
#         accuracy                           0.83       596
#        macro avg       0.85      0.74      0.76       596
#     weighted avg       0.84      0.83      0.81       596
